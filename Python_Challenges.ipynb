# %% [markdown]
# <a href="https://colab.research.google.com/github/KIISIISHERE/Python-Challenges-Tic-Tac-Toe-Guess-the-Number-Game-/blob/main/Python_Challenges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Activity 1 : Tic Tac Toe Game
board = [" " for _ in range(9)]
def print_board():
    print()
    for i in range(3):
        row = board[i*3 : (i+1)*3]
        print(" | ".join(row))
        if i < 2:
            print("--+---+--")
    print()
def check_win(player):
    win_conditions = [
        [0,1,2], [3,4,5], [6,7,8], # rows
        [0,3,6], [1,4,7], [2,5,8], # columns
        [0,4,8], [2,4,6] # diagonals
    ]
    return any(all(board[i] == player for i in condition) for condition in win_conditions)
def is_draw():
    return all(cell != " " for cell in board)
def play_game():
    current_player = "X"
    print("Welcome to Tic Tac Toe!")
    print_board()
    while True:
            move = int(input(f"Player {current_player}, enter your move (1-9): ")) - 1
            if board[move] != " ":
                print("That spot is already taken. Try again.")
                continue
            board[move] = current_player
            print_board()
            if check_win(current_player):
                print(f"Player {current_player} wins!")
                break
            if is_draw():
                print("It's a draw!")
                break
            current_player = "O" if current_player == "X" else "X"

play_game()
# Out:
# Welcome to Tic Tac Toe!
#
#   |   |
# --+---+--
#   |   |
# --+---+--
#   |   |
#
# Player X, enter your move (1-9): 1
#
# X |   |
# --+---+--
#   |   |
# --+---+--
#   |   |
#
# Player O, enter your move (1-9): 9
#
# X |   |
# --+---+--
#   |   |
# --+---+--
#   |   | O
#
# Player X, enter your move (1-9): 6
#
# X |   |
# --+---+--
#   |   | X
# --+---+--
#   |   | O
#
# Player O, enter your move (1-9): 8
#
# X |   |
# --+---+--
#   |   | X
# --+---+--
#   | O | O
#
# Player X, enter your move (1-9): 7
#
# X |   |
# --+---+--
#   |   | X
# --+---+--
# X | O | O
#
# Player O, enter your move (1-9): 2
#
# X | O |
# --+---+--
#   |   | X
# --+---+--
# X | O | O
#
# Player X, enter your move (1-9): 4
#
# X | O |
# --+---+--
# X |   | X
# --+---+--
# X | O | O
#
# Player X wins!

# %%
# Activity 2 : Guess The Number Game
import random
n = random.randint(1, 100)
while True:
    g = int(input("Guess the number: "))
    if g < n:
        print("To low!")
    elif g > n:
        print("To high!")
    else:
            print("Correct!")
            break
# Out:
# Guess the number: 100
# To high!
# Guess the number: 90
# To high!
# Guess the number: 99
# To high!
# Guess the number: 60
# To low!
# Guess the number: 79
# To high!
# Guess the number: 60
# To low!
# Guess the number: 65
# To high!
# Guess the number: 64
# To high!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-665511cbd133> in <cell line: 0>()
#       3 n = random.randint(1, 100)
#       4 while True:
# ----> 5     g = int(input("Guess the number: "))
#       6     if g < n:
#       7         print("To low!")
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
